# %%
# %env IMAGINATION_IP=imagination.mat.ucsb.edu
# %env SSH_USERNAME=raghav
# %env SSH_PKEY=/Users/raghav/.ssh/id_rsa
# %env LOCAL_PORT=56789
# %run main.py
import os

print("IMAGINATION_IP:", os.getenv('IMAGINATION_IP'))
print("SSH_USERNAME:", os.getenv('SSH_USERNAME'))
print("SSH_PKEY:", os.getenv('SSH_PKEY'))
print("LOCAL_PORT:", os.getenv('LOCAL_PORT'))
# Out:
# env: IMAGINATION_IP=imagination.mat.ucsb.edu
# env: SSH_USERNAME=raghav
# env: SSH_PKEY=/Users/raghav/.ssh/id_rsa
# env: LOCAL_PORT=56789
# PYTORCH_MPS_HIGH_WATERMARK_RATIO: None
# PYTORCH_ENABLE_MPS_FALLBACK: 1
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/nightly/cpu
# ...
# IMAGINATION_IP: imagination.mat.ucsb.edu
# SSH_USERNAME: raghav
# SSH_PKEY: /Users/raghav/.ssh/id_rsa
# IMAGINATION_PORT: 11434
# LOCAL_PORT: 56789
# Starting SSH tunnel...
# 2024-07-10 11:43:07,086| ERROR   | Could not open connection to gateway
# ---------------------------------------------------------------------------
# BaseSSHTunnelForwarderError               Traceback (most recent call last)
# File ~/LLM-FINETUNER/main.py:193
#     191 if __name__ == "__main__":
#     192     print("Starting SSH tunnel...")
# --> 193     start_tunnel(
#     194         remote_server=IMAGINATION_IP,
#     195         ssh_username=SSH_USERNAME,
#     196         ssh_pkey=SSH_PKEY,
# ...
